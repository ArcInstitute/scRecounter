# %% [markdown]
# # Goals
#
# * Check on h5ad files created by gcp-loader pipeline

# %%
import scanpy as sc

# %%
#infile = "/processed_datasets/scRecount/scRecounter/tmp/prod3_dev_output/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX19498727.h5ad.gz"
infile = "/processed_datasets/scRecount/scRecounter/tmp/prod3_dev_output/h5ad/Velocyto/Arabidopsis_thaliana/SRX19498713.h5ad.gz"

# %%
adata = sc.read_h5ad(infile, backed='r')
adata
# Out:
# AnnData object with n_obs × n_vars = 4730 × 31109 backed at '/processed_datasets/scRecount/scRecounter/tmp/prod3_dev_output/h5ad/Velocyto/Arabidopsis_thaliana/SRX19498713.h5ad.gz'
#     obs: 'gene_count', 'umi_count', 'SRX_accession'
#     var: 'gene_ids', 'feature_types'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
adata.layers['spliced']
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'float64'
# 	with 4096390 stored elements and shape (4730, 31109)>

# %%
adata.layers['unspliced']
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'float64'
# 	with 4096390 stored elements and shape (4730, 31109)>
