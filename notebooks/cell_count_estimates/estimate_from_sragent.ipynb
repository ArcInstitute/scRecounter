# %% [markdown]
# # Goal
#
# * Provide an estimate of total cell count in the SRA based on the data in the scBaseCamp SQL database

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
import pandas as pd
import plotnine as pn
from pypika import Query, Table, Field, Column, Criterion

# %%
from SRAgent.db.connect import db_connect
from SRAgent.db.utils import db_list_tables, db_glimpse_tables, db_get_table, execute_query
from SRAgent.db.get import db_find_srx

# %%
# set plotnine theme to bw
pn.theme_set(pn.theme_bw())

# set pandas row display max
pd.set_option('display.max_rows', 10)

# %%
# set to prod database
os.environ['DYNACONF'] = 'prod'

# %%
# list database tables
with db_connect() as conn:
    print("\n".join(db_list_tables(conn)))
# Out:
# screcounter_star_results
# eval
# scbasecamp_metadata
# screcounter_trace
# srx_srr
# srx_metadata
# screcounter_log
# scbasecamp_metadata_tmp
# screcounter_star_params

# %% [markdown]
# # Load

# %%
target_organisms = [
    "Homo sapiens", 
    "Mus musculus", 
    "Gallus gallus", 
    "Macaca mulatta",
    "Danio rerio", 
    "Callithrix jacchus", 
    "Pan troglodytes", 
    "Sus scrofa", 
    "Rattus norvegicus",
    "Drosophila melanogaster", 
    "Arabidopsis thaliana",
    "Canis lupus", 
    "Heterocephalus glaber", 
    "Zea mays", 
    "Ovis aries",
    "Bos taurus", 
    "Caenorhabditis elegans",
    "Equus caballus",
    "Schistosoma mansoni", 
    "Oryctolagus cuniculus", 
    "Solanum lycopersicum",
    "Oryza sativa",
    "Gorilla gorilla",
    "Anopheles gambiae",
    "Xenopus tropicalis"
]
len(target_organisms)
# Out:
# 25

# %%
# load database metadata
tbl = Table("srx_metadata")

stmt = Query \
    .from_(tbl) \
    .select(
        tbl.srx_accession, tbl.organism, tbl.tissue, tbl.lib_prep, 
        tbl.tech_10x, tbl.czi_collection_id
    ) \
    .where(tbl.organism.isin(target_organisms))

with db_connect() as conn:
    df_srx_meta = pd.read_sql(str(stmt), conn)
df_srx_meta
# Out:
#       srx_accession        organism       tissue      lib_prep  \
# 0        SRX3809288    Mus musculus   cerebellum  10x_Genomics
# 1       SRX13549220   Gallus gallus        liver  10x_Genomics
# 2       SRX10417554  Macaca mulatta  fetal lungs  10x_Genomics
# 3        SRX2003956    Homo sapiens     pancreas      CEL-seq2
# 4        ERX2814788    Homo sapiens         skin    Smart-seq2
# ...             ...             ...          ...           ...
# 72018   SRX27713793    Mus musculus       kidney         other
# 72019   SRX27713794    Mus musculus       kidney         other
# 72020   SRX27713795    Mus musculus       kidney         other
# 72021   SRX27713796    Mus musculus       kidney         other
# 72022   SRX27713797    Mus musculus       kidney         other
#
#              tech_10x                     czi_collection_id
# 0         3_prime_gex  d86517f0-fa7e-4266-b82e-a521350d6d36
# 1         3_prime_gex  74e10dc4-cbb2-4605-a189-8a1cd8e44d8c
# 2         3_prime_gex  6e067060-f7e4-466c-86f3-ec3dd33c0381
# 3      not_applicable  6e8c5415-302c-492a-a5f9-f29c57ff18fb
# 4      not_applicable                                  None
# ...               ...                                   ...
# 72018  not_applicable                                  None
# 72019  not_applicable                                  None
# 72020  not_applicable                                  None
# 72021  not_applicable                                  None
# 72022  not_applicable                                  None
#
# [72023 rows x 6 columns]

# %%
# load tissue categories
df_tissue_cats = pd.read_csv("../tissues/data/2025-03-11_tissue_categories.csv")
df_tissue_cats
# Out:
#                                                  tissue      category
# 0                                      2 layer spheroid         other
# 1                 3 layer spheroid channel 1,epithelial         other
# 2                            3 layer spheroid channel 2         other
# 3                                 3D healthy skin model  skin of body
# 4                                            A549 cells          lung
# ...                                                 ...           ...
# 5613  whole animal, developmental stages: 26, 28, 30...         other
# 5614                                  whole skin tissue  skin of body
# 5615                                               wing         other
# 5616                                  zebrafish embryos        embryo
# 5617                           brain's right hemisphere         brain
#
# [5618 rows x 2 columns]

# %%
# join on tissue
df_srx_meta = df_srx_meta.merge(df_tissue_cats, on="tissue", how="left").rename(columns={"category": "tissue_category"})
df_srx_meta
# Out:
#       srx_accession        organism       tissue      lib_prep  \
# 0        SRX3809288    Mus musculus   cerebellum  10x_Genomics
# 1       SRX13549220   Gallus gallus        liver  10x_Genomics
# 2       SRX10417554  Macaca mulatta  fetal lungs  10x_Genomics
# 3        SRX2003956    Homo sapiens     pancreas      CEL-seq2
# 4        ERX2814788    Homo sapiens         skin    Smart-seq2
# ...             ...             ...          ...           ...
# 72018   SRX27713793    Mus musculus       kidney         other
# 72019   SRX27713794    Mus musculus       kidney         other
# 72020   SRX27713795    Mus musculus       kidney         other
# 72021   SRX27713796    Mus musculus       kidney         other
# 72022   SRX27713797    Mus musculus       kidney         other
#
#              tech_10x                     czi_collection_id tissue_category
# 0         3_prime_gex  d86517f0-fa7e-4266-b82e-a521350d6d36           brain
# 1         3_prime_gex  74e10dc4-cbb2-4605-a189-8a1cd8e44d8c           liver
# 2         3_prime_gex  6e067060-f7e4-466c-86f3-ec3dd33c0381            lung
# 3      not_applicable  6e8c5415-302c-492a-a5f9-f29c57ff18fb        pancreas
# 4      not_applicable                                  None    skin of body
# ...               ...                                   ...             ...
# 72018  not_applicable                                  None          kidney
# 72019  not_applicable                                  None          kidney
# 72020  not_applicable                                  None          kidney
# 72021  not_applicable                                  None          kidney
# 72022  not_applicable                                  None          kidney
#
# [72023 rows x 7 columns]

# %%
# load processed datasets
tbl1 = Table("screcounter_star_results")
tbl2 = Table("scbasecamp_metadata")

# Create a subquery for distinct SRX accessions from scbasecamp_metadata
subquery = Query.from_(tbl2).select(tbl2.srx_accession).distinct()

stmt = Query \
    .from_(tbl1) \
    .select(
        tbl1.sample, tbl1.estimated_number_of_cells
    ) \
    .where(tbl1.sample.isin(subquery)) \
    .where(tbl1.feature == "gene_ex50")

with db_connect() as conn:
    df_star = pd.read_sql(str(stmt), conn)
df_star
# Out:
#             sample  estimated_number_of_cells
# 0      ERX10024831                       2290
# 1      ERX10086874                       2266
# 2      ERX10396585                       4875
# 3      ERX10855741                       4299
# 4       ERX9427783                       6404
# ...            ...                        ...
# 27477  SRX25483696                      19691
# 27478  SRX25484283                      10031
# 27479  SRX25483870                      10822
# 27480  SRX25491706                       1308
# 27481  SRX25487967                       4414
#
# [27482 rows x 2 columns]

# %%
# merge star results with srx_metadata
df_srx_meta = df_srx_meta.merge(df_star, left_on="srx_accession", right_on="sample", how="left").drop(columns=["sample"])
df_srx_meta["estimated_number_of_cells"] = df_srx_meta["estimated_number_of_cells"].fillna(0).astype(int)
df_srx_meta
# Out:
#       srx_accession        organism       tissue      lib_prep  \
# 0        SRX3809288    Mus musculus   cerebellum  10x_Genomics
# 1       SRX13549220   Gallus gallus        liver  10x_Genomics
# 2       SRX10417554  Macaca mulatta  fetal lungs  10x_Genomics
# 3        SRX2003956    Homo sapiens     pancreas      CEL-seq2
# 4        ERX2814788    Homo sapiens         skin    Smart-seq2
# ...             ...             ...          ...           ...
# 72018   SRX27713793    Mus musculus       kidney         other
# 72019   SRX27713794    Mus musculus       kidney         other
# 72020   SRX27713795    Mus musculus       kidney         other
# 72021   SRX27713796    Mus musculus       kidney         other
# 72022   SRX27713797    Mus musculus       kidney         other
#
#              tech_10x                     czi_collection_id tissue_category  \
# 0         3_prime_gex  d86517f0-fa7e-4266-b82e-a521350d6d36           brain
# 1         3_prime_gex  74e10dc4-cbb2-4605-a189-8a1cd8e44d8c           liver
# 2         3_prime_gex  6e067060-f7e4-466c-86f3-ec3dd33c0381            lung
# 3      not_applicable  6e8c5415-302c-492a-a5f9-f29c57ff18fb        pancreas
# 4      not_applicable                                  None    skin of body
# ...               ...                                   ...             ...
# 72018  not_applicable                                  None          kidney
# 72019  not_applicable                                  None          kidney
# 72020  not_applicable                                  None          kidney
# 72021  not_applicable                                  None          kidney
# 72022  not_applicable                                  None          kidney
#
#        estimated_number_of_cells
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 72018                          0
# 72019                          0
# 72020                          0
# 72021                          0
# 72022                          0
#
# [72023 rows x 8 columns]

# %%
# load log info 
tbl1 = Table("screcounter_log")

stmt = Query \
    .from_(tbl1) \
    .select(tbl1.sample) \
    .distinct()

with db_connect() as conn:
    df_logs = pd.read_sql(str(stmt), conn)
    df_logs["screcounter_processed"] = "yes"
df_logs
# Out:
#             sample screcounter_processed
# 0      SRX17797421                   yes
# 1      SRX20260871                   yes
# 2      SRX22966162                   yes
# 3       ERX9273500                   yes
# 4      SRX22288178                   yes
# ...            ...                   ...
# 37034  SRX20904842                   yes
# 37035  SRX21870305                   yes
# 37036  SRX19364020                   yes
# 37037  SRX26596070                   yes
# 37038  SRX23392066                   yes
#
# [37039 rows x 2 columns]

# %%
# merge with df_srx_meta
df_srx_meta = df_srx_meta.merge(df_logs, left_on="srx_accession", right_on="sample", how="left").drop(columns=["sample"])
df_srx_meta["screcounter_processed"] = df_srx_meta["screcounter_processed"].fillna("no")
df_srx_meta
# Out:
#       srx_accession        organism       tissue      lib_prep  \
# 0        SRX3809288    Mus musculus   cerebellum  10x_Genomics
# 1       SRX13549220   Gallus gallus        liver  10x_Genomics
# 2       SRX10417554  Macaca mulatta  fetal lungs  10x_Genomics
# 3        SRX2003956    Homo sapiens     pancreas      CEL-seq2
# 4        ERX2814788    Homo sapiens         skin    Smart-seq2
# ...             ...             ...          ...           ...
# 72018   SRX27713793    Mus musculus       kidney         other
# 72019   SRX27713794    Mus musculus       kidney         other
# 72020   SRX27713795    Mus musculus       kidney         other
# 72021   SRX27713796    Mus musculus       kidney         other
# 72022   SRX27713797    Mus musculus       kidney         other
#
#              tech_10x                     czi_collection_id tissue_category  \
# 0         3_prime_gex  d86517f0-fa7e-4266-b82e-a521350d6d36           brain
# 1         3_prime_gex  74e10dc4-cbb2-4605-a189-8a1cd8e44d8c           liver
# 2         3_prime_gex  6e067060-f7e4-466c-86f3-ec3dd33c0381            lung
# 3      not_applicable  6e8c5415-302c-492a-a5f9-f29c57ff18fb        pancreas
# 4      not_applicable                                  None    skin of body
# ...               ...                                   ...             ...
# 72018  not_applicable                                  None          kidney
# 72019  not_applicable                                  None          kidney
# 72020  not_applicable                                  None          kidney
# 72021  not_applicable                                  None          kidney
# 72022  not_applicable                                  None          kidney
#
#        estimated_number_of_cells screcounter_processed
# 0                              0                    no
# 1                              0                    no
# 2                              0                    no
# 3                              0                    no
# 4                              0                    no
# ...                          ...                   ...
# 72018                          0                    no
# 72019                          0                    no
# 72020                          0                    no
# 72021                          0                    no
# 72022                          0                    no
#
# [72023 rows x 9 columns]

# %% [markdown]
# # Cell count estimates

# %% [markdown]
# ## Total cell count

# %%
# distrubtion of cell counts
df_srx_meta["estimated_number_of_cells"].describe()
# Out:
# count     72023.000000
# mean       2943.985671
# std        5589.841412
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%        4689.000000
# max      148051.000000
# Name: estimated_number_of_cells, dtype: float64

# %%
# distribution of cell counts (no zeros)
df_srx_meta[df_srx_meta["estimated_number_of_cells"] > 0]["estimated_number_of_cells"].describe()
# Out:
# count     27482.000000
# mean       7715.402081
# std        6713.821956
# min           9.000000
# 25%        3642.000000
# 50%        6472.500000
# 75%        9910.000000
# max      148051.000000
# Name: estimated_number_of_cells, dtype: float64

# %%
# average number of cells per sample
cells_per_sample = float(df_srx_meta[df_srx_meta["estimated_number_of_cells"] > 0]["estimated_number_of_cells"].mean())
cells_per_sample
# Out:
# 7715.4020813623465

# %%
# fraction of samples that yield cells
fraction_yields_cells = 1 - (df_srx_meta[(df_srx_meta["screcounter_processed"] == "yes") & (df_srx_meta["estimated_number_of_cells"] == 0)].shape[0] / df_srx_meta.shape[0])
fraction_yields_cells
# Out:
# 0.8681254599225248

# %%
# samples yet to be processed
num_to_process = df_srx_meta[df_srx_meta["screcounter_processed"] == "no"].shape[0]
num_to_process
# Out:
# 35043

# %%
# estimate total number of cells after processing all
total_estimated_cells = cells_per_sample * num_to_process * fraction_yields_cells + df_srx_meta["estimated_number_of_cells"].sum()
print(f"Estimated cell count: {int(total_estimated_cells)}")
# Out:
# Estimated cell count: 446750485

# %% [markdown]
# ## Per-organism

# %%
df_org = []
for organism in target_organisms:
    # filter 
    df = df_srx_meta[df_srx_meta["organism"] == organism].copy()
    # average number of cells per sample
    cells_per_sample = float(df[df["estimated_number_of_cells"] > 0]["estimated_number_of_cells"].mean())
    # fraction of samples that yield cells
    fraction_yields_cells = 1 - (df[(df["screcounter_processed"] == "yes") & (df["estimated_number_of_cells"] == 0)].shape[0] / df.shape[0])
    # samples yet to be processed
    num_to_process = df[df["screcounter_processed"] == "no"].shape[0]
    # estimate total number of cells after processing all
    total_estimated_cells = cells_per_sample * num_to_process * fraction_yields_cells + df["estimated_number_of_cells"].sum()
    df_org.append([organism, total_estimated_cells])

# convert to dataframe
df_org = pd.DataFrame(df_org, columns=["organism", "total_estimated_cells"])
df_org = df_org[~df_org["total_estimated_cells"].isna()]
pd.set_option('display.max_rows', None)
df_org
# Out:
#                    organism  total_estimated_cells
# 0              Homo sapiens           1.917599e+08
# 1              Mus musculus           1.849810e+08
# 2             Gallus gallus           3.944710e+07
# 3            Macaca mulatta           6.561505e+06
# 4               Danio rerio           4.504285e+06
# 5        Callithrix jacchus           3.224514e+06
# 6           Pan troglodytes           1.104877e+06
# 7                Sus scrofa           2.828977e+06
# 9   Drosophila melanogaster           1.911935e+06
# 10     Arabidopsis thaliana           2.096516e+06
# 12    Heterocephalus glaber           4.609580e+05
# 13                 Zea mays           8.058669e+05
# 14               Ovis aries           6.799525e+05
# 15               Bos taurus           5.805338e+05
# 16   Caenorhabditis elegans           3.663357e+05
# 17           Equus caballus           6.984450e+05
# 18      Schistosoma mansoni           1.879350e+05
# 19    Oryctolagus cuniculus           4.847402e+05
# 20     Solanum lycopersicum           4.776305e+05
# 21             Oryza sativa           2.682788e+05
# 22          Gorilla gorilla           9.351000e+03

# %%
# add total processed cells
df_exist_cells = df_srx_meta.groupby("organism")["estimated_number_of_cells"].sum().reset_index().rename(columns={"estimated_number_of_cells": "total_processed_cells"})
df_org = df_org.merge(df_exist_cells, on="organism", how="left")
df_org["delta"] = df_org["total_estimated_cells"] - df_org["total_processed_cells"]
df_org
# Out:
#                    organism  total_estimated_cells  total_processed_cells  \
# 0              Homo sapiens           1.917599e+08              101500123
# 1              Mus musculus           1.849810e+08               94179912
# 2             Gallus gallus           3.944710e+07                 683753
# 3            Macaca mulatta           6.561505e+06                3879253
# 4               Danio rerio           4.504285e+06                3707297
# 5        Callithrix jacchus           3.224514e+06                 160982
# 6           Pan troglodytes           1.104877e+06                 312701
# 7                Sus scrofa           2.828977e+06                1809380
# 8   Drosophila melanogaster           1.911935e+06                1662282
# 9      Arabidopsis thaliana           2.096516e+06                1618082
# 10    Heterocephalus glaber           4.609580e+05                 460958
# 11                 Zea mays           8.058669e+05                 271229
# 12               Ovis aries           6.799525e+05                 197146
# 13               Bos taurus           5.805338e+05                 410785
# 14   Caenorhabditis elegans           3.663357e+05                 278649
# 15           Equus caballus           6.984450e+05                 107684
# 16      Schistosoma mansoni           1.879350e+05                  33165
# 17    Oryctolagus cuniculus           4.847402e+05                 396294
# 18     Solanum lycopersicum           4.776305e+05                 103318
# 19             Oryza sativa           2.682788e+05                 252336
# 20          Gorilla gorilla           9.351000e+03                   9351
#
#            delta
# 0   9.025976e+07
# 1   9.080109e+07
# 2   3.876334e+07
# 3   2.682252e+06
# 4   7.969883e+05
# 5   3.063532e+06
# 6   7.921759e+05
# 7   1.019597e+06
# 8   2.496532e+05
# 9   4.784345e+05
# 10  0.000000e+00
# 11  5.346379e+05
# 12  4.828065e+05
# 13  1.697488e+05
# 14  8.768675e+04
# 15  5.907610e+05
# 16  1.547700e+05
# 17  8.844624e+04
# 18  3.743125e+05
# 19  1.594280e+04
# 20  0.000000e+00

# %%
# amount left to obtain from each organism
df_org["delta"].describe()
# Out:
# count    2.100000e+01
# mean     1.101933e+07
# std      2.771694e+07
# min      0.000000e+00
# 25%      1.547700e+05
# 50%      4.828065e+05
# 75%      1.019597e+06
# max      9.080109e+07
# Name: delta, dtype: float64

# %%
pd.set_option('display.max_rows', 10)

# %%
# plot cells per organism
## order by total estimated cells
df_org["organism"] = pd.Categorical(
    df_org["organism"], 
    categories=df_org.groupby(["organism"]).sum().sort_values(by="total_estimated_cells", ascending=False).index
)

# plot
p = (
    pn.ggplot(df_org, pn.aes(x="organism", y="total_estimated_cells")) +
    pn.geom_col() +
    pn.geom_errorbar(pn.aes(ymin="total_processed_cells", ymax="total_processed_cells"), width=0.5, color="red") +
    pn.scale_y_log10() +
    pn.labs(x="Organism", y="Estimated cell count") +
    pn.theme(
        axis_text_x=pn.element_text(angle=45, hjust=1),
        figure_size=(6, 3.5)
    )
)
p
# Out:
# /home/nickyoungblut/miniforge3/envs/SRAgent_nb/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# # sessionInfo

# %%
# !mamba list
# Out:
# # packages in environment at /home/nickyoungblut/miniforge3/envs/SRAgent_nb:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# aiohappyeyeballs          2.4.3                    pypi_0    pypi
# aiohttp                   3.10.10                  pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.6.2.post1              pypi_0    pypi
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# attrs                     24.2.0                   pypi_0    pypi
# beautifulsoup4            4.12.3                   pypi_0    pypi
# biopython                 1.84                     pypi_0    pypi
# brotli                    1.1.0                hb9d3cd8_2    conda-forge
# brotli-bin                1.1.0                hb9d3cd8_2    conda-forge
# build                     1.2.2.post1              pypi_0    pypi
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.3               heb4867d_0    conda-forge
# ca-certificates           2025.1.31            hbcca054_0    conda-forge
# cachetools                5.5.0                    pypi_0    pypi
# certifi                   2024.8.30                pypi_0    pypi
# cffi                      1.17.1                   pypi_0    pypi
# charset-normalizer        3.4.0                    pypi_0    pypi
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# contourpy                 1.3.1           py312h68727a3_0    conda-forge
# cryptography              44.0.1                   pypi_0    pypi
# curl                      8.10.1               hbbe4b11_0    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_1    conda-forge
# dataclasses-json          0.6.7                    pypi_0    pypi
# db-dtypes                 1.3.1                    pypi_0    pypi
# debugpy                   1.8.7           py312h2ec8cdc_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# distro                    1.9.0                    pypi_0    pypi
# docutils                  0.21.2                   pypi_0    pypi
# dynaconf                  3.2.6                    pypi_0    pypi
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.1.0              pyhd8ed1ab_0    conda-forge
# fonttools                 4.56.0          py312h178313f_0    conda-forge
# freetype                  2.12.1               h267a509_2    conda-forge
# frozenlist                1.5.0                    pypi_0    pypi
# google-api-core           2.23.0                   pypi_0    pypi
# google-auth               2.36.0                   pypi_0    pypi
# google-auth-oauthlib      1.2.1                    pypi_0    pypi
# google-cloud              0.34.0                   pypi_0    pypi
# google-cloud-bigquery     3.27.0                   pypi_0    pypi
# google-cloud-bigquery-storage 2.27.0                   pypi_0    pypi
# google-cloud-core         2.4.1                    pypi_0    pypi
# google-cloud-secret-manager 2.22.0                   pypi_0    pypi
# google-cloud-storage      2.19.0                   pypi_0    pypi
# google-crc32c             1.6.0                    pypi_0    pypi
# google-resumable-media    2.7.2                    pypi_0    pypi
# googleapis-common-protos  1.66.0                   pypi_0    pypi
# greenlet                  3.1.1                    pypi_0    pypi
# grpc-google-iam-v1        0.13.1                   pypi_0    pypi
# grpcio                    1.68.1                   pypi_0    pypi
# grpcio-status             1.68.1                   pypi_0    pypi
# gspread                   6.1.4                    pypi_0    pypi
# gspread-dataframe         4.0.0                    pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# httpcore                  1.0.6                    pypi_0    pypi
# httpx                     0.27.2                   pypi_0    pypi
# httpx-sse                 0.4.0                    pypi_0    pypi
# icu                       70.1                 h27087fc_0    conda-forge
# id                        1.5.0                    pypi_0    pypi
# idna                      3.10                     pypi_0    pypi
# importlib-metadata        8.5.0              pyha770c72_0    conda-forge
# ipykernel                 6.29.5             pyh3099207_0    conda-forge
# ipython                   8.29.0             pyh707e725_0    conda-forge
# jaraco-classes            3.4.0                    pypi_0    pypi
# jaraco-context            6.0.1                    pypi_0    pypi
# jaraco-functools          4.1.0                    pypi_0    pypi
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# jeepney                   0.8.0                    pypi_0    pypi
# jiter                     0.7.0                    pypi_0    pypi
# jsonpatch                 1.33                     pypi_0    pypi
# jsonpointer               3.0.0                    pypi_0    pypi
# jupyter_client            8.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2              pyh31011fe_1    conda-forge
# keyring                   25.6.0                   pypi_0    pypi
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.8           py312h84d6215_0    conda-forge
# krb5                      1.21.3               h659f571_0    conda-forge
# langchain                 0.3.7                    pypi_0    pypi
# langchain-community       0.3.5                    pypi_0    pypi
# langchain-core            0.3.15                   pypi_0    pypi
# langchain-openai          0.2.6                    pypi_0    pypi
# langchain-text-splitters  0.3.2                    pypi_0    pypi
# langchainhub              0.1.21                   pypi_0    pypi
# langgraph                 0.2.45                   pypi_0    pypi
# langgraph-checkpoint      2.0.2                    pypi_0    pypi
# langgraph-sdk             0.1.35                   pypi_0    pypi
# langsmith                 0.1.140                  pypi_0    pypi
# lcms2                     2.17                 h717163a_0    conda-forge
# ld_impl_linux-64          2.43                 h712a8e2_2    conda-forge
# lerc                      4.0.0                h27087fc_0    conda-forge
# libblas                   3.9.0           31_h59b9bed_openblas    conda-forge
# libbrotlicommon           1.1.0                hb9d3cd8_2    conda-forge
# libbrotlidec              1.1.0                hb9d3cd8_2    conda-forge
# libbrotlienc              1.1.0                hb9d3cd8_2    conda-forge
# libcblas                  3.9.0           31_he106b2a_openblas    conda-forge
# libcurl                   8.10.1               hbbe4b11_0    conda-forge
# libdeflate                1.23                 h4ddbbb0_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libexpat                  2.6.4                h5888daf_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc                    14.2.0               h77fa898_1    conda-forge
# libgcc-ng                 14.2.0               h69a702a_1    conda-forge
# libgfortran               14.2.0               h69a702a_2    conda-forge
# libgfortran5              14.2.0               hf1ad2bd_2    conda-forge
# libgomp                   14.2.0               h77fa898_1    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# libjpeg-turbo             3.0.0                hd590300_1    conda-forge
# liblapack                 3.9.0           31_h7ac8fdf_openblas    conda-forge
# liblzma                   5.6.4                hb9d3cd8_0    conda-forge
# libnghttp2                1.64.0               h161d5f1_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libopenblas               0.3.29          pthreads_h94d23a6_0    conda-forge
# libpng                    1.6.47               h943b412_0    conda-forge
# libsodium                 1.0.20               h4ab18f5_0    conda-forge
# libsqlite                 3.47.0               hadc24fc_1    conda-forge
# libssh2                   1.11.0               h0841786_0    conda-forge
# libstdcxx                 14.2.0               hc0a3c3a_1    conda-forge
# libstdcxx-ng              14.2.0               h4852527_1    conda-forge
# libtiff                   4.7.0                hd9ff511_3    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libwebp-base              1.5.0                h851e524_0    conda-forge
# libxcb                    1.17.0               h8a09558_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxml2                   2.9.14               h22db469_4    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# markdown-it-py            3.0.0                    pypi_0    pypi
# marshmallow               3.23.1                   pypi_0    pypi
# matplotlib-base           3.10.1          py312hd3ec401_0    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# mdurl                     0.1.2                    pypi_0    pypi
# mizani                    0.13.1             pyhd8ed1ab_0    conda-forge
# more-itertools            10.6.0                   pypi_0    pypi
# msgpack                   1.1.0                    pypi_0    pypi
# multidict                 6.1.0                    pypi_0    pypi
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mypy-extensions           1.0.0                    pypi_0    pypi
# ncbi-vdb                  3.1.1                h4ac6f70_2    bioconda
# ncurses                   6.5                  he02047a_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# nh3                       0.2.21                   pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# openai                    1.57.2                   pypi_0    pypi
# openjpeg                  2.5.3                h5fbd93e_0    conda-forge
# openssl                   3.4.1                h7b32b05_0    conda-forge
# orjson                    3.10.11                  pypi_0    pypi
# ossuuid                   1.6.2             hf484d3e_1000    conda-forge
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# pandas                    2.2.3           py312hf9745cd_1    conda-forge
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# patsy                     1.0.1              pyhd8ed1ab_1    conda-forge
# perl                      5.26.2            h36c2ea0_1008    conda-forge
# perl-app-cpanminus        1.7044                  pl526_1    bioconda
# perl-business-isbn        3.004                   pl526_0    bioconda
# perl-business-isbn-data   20140910.003            pl526_0    bioconda
# perl-carp                 1.38                    pl526_3    bioconda
# perl-constant             1.33                    pl526_1    bioconda
# perl-data-dumper          2.173                   pl526_0    bioconda
# perl-encode               2.88                    pl526_1    bioconda
# perl-exporter             5.72                    pl526_1    bioconda
# perl-extutils-makemaker   7.36                    pl526_1    bioconda
# perl-file-path            2.16                    pl526_0    bioconda
# perl-file-temp            0.2304                  pl526_2    bioconda
# perl-mime-base64          3.15                    pl526_1    bioconda
# perl-parent               0.236                   pl526_1    bioconda
# perl-uri                  1.76                    pl526_0    bioconda
# perl-xml-libxml           2.0132          pl526h7ec2d77_1    bioconda
# perl-xml-namespacesupport 1.12                    pl526_0    bioconda
# perl-xml-sax              1.02                    pl526_0    bioconda
# perl-xml-sax-base         1.09                    pl526_0    bioconda
# perl-xsloader             0.24                    pl526_0    bioconda
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    11.1.0          py312h80c1187_0    conda-forge
# pip                       24.3.1             pyh8b19718_0    conda-forge
# pkginfo                   1.12.1.2                 pypi_0    pypi
# platformdirs              4.3.6              pyhd8ed1ab_0    conda-forge
# plotnine                  0.14.5             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.48             pyha770c72_0    conda-forge
# propcache                 0.2.0                    pypi_0    pypi
# proto-plus                1.25.0                   pypi_0    pypi
# protobuf                  5.29.1                   pypi_0    pypi
# psutil                    6.1.0           py312h66e93f0_0    conda-forge
# psycopg2-binary           2.9.10                   pypi_0    pypi
# pthread-stubs             0.4               hb9d3cd8_1002    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pyarrow                   18.1.0                   pypi_0    pypi
# pyasn1                    0.6.1                    pypi_0    pypi
# pyasn1-modules            0.4.1                    pypi_0    pypi
# pycparser                 2.22                     pypi_0    pypi
# pydantic                  2.9.2                    pypi_0    pypi
# pydantic-core             2.23.4                   pypi_0    pypi
# pydantic-settings         2.6.1                    pypi_0    pypi
# pyee                      12.0.0                   pypi_0    pypi
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.2.1              pyhd8ed1ab_0    conda-forge
# pypika                    0.48.9                   pypi_0    pypi
# pyproject-hooks           1.2.0                    pypi_0    pypi
# python                    3.12.7          hc5c86c4_0_cpython    conda-forge
# python-dateutil           2.9.0.post0              pypi_0    pypi
# python-dotenv             1.0.1                    pypi_0    pypi
# python-tzdata             2025.1             pyhd8ed1ab_0    conda-forge
# python_abi                3.12                    5_cp312    conda-forge
# pytz                      2024.2                   pypi_0    pypi
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     26.2.0          py312hbf22597_3    conda-forge
# qhull                     2020.2               h434a139_5    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# readme-renderer           44.0                     pypi_0    pypi
# regex                     2024.11.6                pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# requests-oauthlib         2.0.0                    pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# rfc3986                   2.0.0                    pypi_0    pypi
# rich                      13.9.4                   pypi_0    pypi
# rsa                       4.9                      pypi_0    pypi
# scipy                     1.15.2          py312ha707e6e_0    conda-forge
# secretstorage             3.3.3                    pypi_0    pypi
# setuptools                75.3.0             pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.1                    pypi_0    pypi
# soupsieve                 2.6                      pypi_0    pypi
# sqlalchemy                2.0.35                   pypi_0    pypi
# sra-tools                 3.1.1                h4304569_2    bioconda
# sragent                   0.1.0                    pypi_0    pypi
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.14.4          py312hc0a28a1_0    conda-forge
# tabulate                  0.9.0                    pypi_0    pypi
# tenacity                  9.0.0                    pypi_0    pypi
# tiktoken                  0.8.0                    pypi_0    pypi
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tornado                   6.4.1           py312h66e93f0_1    conda-forge
# tqdm                      4.67.0                   pypi_0    pypi
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# twine                     6.0.1                    pypi_0    pypi
# types-requests            2.32.0.20241016          pypi_0    pypi
# typing-inspect            0.9.0                    pypi_0    pypi
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# tzdata                    2024.2                   pypi_0    pypi
# unicodedata2              16.0.0          py312h66e93f0_0    conda-forge
# urllib3                   2.2.3                    pypi_0    pypi
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# wheel                     0.44.0             pyhd8ed1ab_0    conda-forge
# xmltodict                 0.14.2                   pypi_0    pypi
# xorg-libxau               1.0.12               hb9d3cd8_0    conda-forge
# xorg-libxdmcp             1.1.5                hb9d3cd8_0    conda-forge
# xz                        5.2.6                h166bdaf_0    conda-forge
# yarl                      1.17.1                   pypi_0    pypi
# zeromq                    4.3.5                h3b0a872_6    conda-forge
# zipp                      3.20.2             pyhd8ed1ab_0    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge
